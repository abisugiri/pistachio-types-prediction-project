# %% [markdown]
# # Perkenalan
#
# Abi Rahman Sugiri
#
# FTDS RMT 021

# %% [markdown]
# ## Description
#
# ### Objective
#
# Mmemprediksi dari tipe atau kelas kacang pistachio dari data karateristik pistachio
#
# ### Problem Statement
#
# Mmepermudah dalam mengklasifikasi tipe kacang pistachio dengan mengaplikasikan klasifikasi machine learning

# %% [markdown]
# # Dataset Source

# %% [markdown]
# https://www.kaggle.com/datasets/amirhosseinmirzaie/pistachio-types-detection

# %% [markdown]
# # Importing Libraries

# %%
#Import libraries

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# c:\Users\abisu\miniconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\abisu\miniconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# c:\Users\abisu\miniconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # Loading Data

# %%
#Loading Data
data = pd.read_csv(r'C:\Users\abisu\p1-ftds-021-rmt-m2-abisugiri\h8dsft_P1M2_abi_sugiri.csv')
pd.set_option('display.max_columns', None)
data
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0     73107  1161.8070    442.4074    217.7261        0.8705  305.0946
# 1     89272  1173.1810    460.2551    251.9546        0.8369  337.1419
# 2     60955   999.7890    386.9247    209.1255        0.8414  278.5863
# 3     79537  1439.5129    466.7973    221.2136        0.8806  318.2289
# 4     96395  1352.6740    515.8730    246.5945        0.8784  350.3340
# ...     ...        ...         ...         ...           ...       ...
# 1713  65570  2071.4451    418.0258    217.1458        0.8545  288.9400
# 1714  68849  1441.2590    451.0457    205.2553        0.8905  296.0764
# 1715  90270  1370.5380    428.9636    269.8232        0.7774  339.0211
# 1716  73148  1309.8430    469.0491    208.3141        0.8960  305.1801
# 1717  78780  1324.8831    451.5905    239.3016        0.8481  316.7109
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
#10 awal baris data
data.head(10)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107  1161.8070    442.4074    217.7261        0.8705  305.0946    0.9424
# 1  89272  1173.1810    460.2551    251.9546        0.8369  337.1419    0.9641
# 2  60955   999.7890    386.9247    209.1255        0.8414  278.5863    0.9465
# 3  79537  1439.5129    466.7973    221.2136        0.8806  318.2289    0.9437
# 4  96395  1352.6740    515.8730    246.5945        0.8784  350.3340    0.9549
# 5  74065  1380.5500    405.4317    245.2286        0.7963  307.0871    0.9041
# 6  91533  1915.9561    451.7373    267.9266        0.8051  341.3846    0.9395
# 7  77803  2034.9950    455.4354    270.3713        0.8047  314.7409    0.7967
# 8  90992  1185.5310    468.9019    249.6060        0.8465  340.3742    0.9883
# 9  83311  1208.8810    473.0142    228.6437        0.8754  325.6913    0.9687
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# ...

# %%
#10 akhir baris data
data.tail(10)
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 1708  73903  1240.7260    419.6304    229.3942        0.8374  306.7511
# 1709  66494  1084.0770    421.8923    205.8024        0.8730  290.9687
# 1710  77847  1121.5840    439.2617    230.6991        0.8510  314.8299
# 1711  70937  1149.4840    432.7040    217.6391        0.8643  300.5325
# 1712  84808  1248.8621    483.3014    235.8735        0.8728  328.6045
# 1713  65570  2071.4451    418.0258    217.1458        0.8545  288.9400
# 1714  68849  1441.2590    451.0457    205.2553        0.8905  296.0764
# 1715  90270  1370.5380    428.9636    269.8232        0.7774  339.0211
# 1716  73148  1309.8430    469.0491    208.3141        0.8960  305.1801
# 1717  78780  1324.8831    451.5905    239.3016        0.8481  316.7109
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# 1708    0.9643        76636  0.7372        1.8293     0.6033       0.7310
# ...

# %%
data.shape
# Out:
# (1718, 17)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Pengecekan tipe data
data.dtypes
# Out:
# AREA               int64
# PERIMETER        float64
# MAJOR_AXIS       float64
# MINOR_AXIS       float64
# ECCENTRICITY     float64
# EQDIASQ          float64
# SOLIDITY         float64
# CONVEX_AREA        int64
# EXTENT           float64
# ASPECT_RATIO     float64
# ROUNDNESS        float64
# COMPACTNESS      float64
# SHAPEFACTOR_1    float64
# SHAPEFACTOR_2    float64
# SHAPEFACTOR_3    float64
# SHAPEFACTOR_4    float64
# Class             object
# dtype: object

# %%
#check dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1718 entries, 0 to 1717
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   AREA           1718 non-null   int64
#  1   PERIMETER      1718 non-null   float64
#  2   MAJOR_AXIS     1718 non-null   float64
#  3   MINOR_AXIS     1718 non-null   float64
#  4   ECCENTRICITY   1718 non-null   float64
#  5   EQDIASQ        1718 non-null   float64
#  6   SOLIDITY       1718 non-null   float64
#  7   CONVEX_AREA    1718 non-null   int64
#  8   EXTENT         1718 non-null   float64
#  9   ASPECT_RATIO   1718 non-null   float64
#  10  ROUNDNESS      1718 non-null   float64
#  11  COMPACTNESS    1718 non-null   float64
#  12  SHAPEFACTOR_1  1718 non-null   float64
#  13  SHAPEFACTOR_2  1718 non-null   float64
#  14  SHAPEFACTOR_3  1718 non-null   float64
#  15  SHAPEFACTOR_4  1718 non-null   float64
#  16  Class          1718 non-null   object
# ...

# %%
#Checking for missing values

data.isnull().sum()
# Out:
# AREA             0
# PERIMETER        0
# MAJOR_AXIS       0
# MINOR_AXIS       0
# ECCENTRICITY     0
# EQDIASQ          0
# SOLIDITY         0
# CONVEX_AREA      0
# EXTENT           0
# ASPECT_RATIO     0
# ROUNDNESS        0
# COMPACTNESS      0
# SHAPEFACTOR_1    0
# SHAPEFACTOR_2    0
# SHAPEFACTOR_3    0
# SHAPEFACTOR_4    0
# Class            0
# dtype: int64

# %% [markdown]
# tidak ada missing value di dalam dataset

# %%
data.describe()
# Out:
#                 AREA    PERIMETER   MAJOR_AXIS   MINOR_AXIS  ECCENTRICITY  \
# count    1718.000000  1718.000000  1718.000000  1718.000000   1718.000000
# mean    79871.952852  1421.797588   446.206444   238.193128      0.840347
# std     12968.217051   373.408835    31.885328    30.426445      0.049026
# min     29808.000000   858.363000   321.425500   133.509600      0.504900
# 25%     71898.500000  1169.633225   426.554100   217.875475      0.817500
# 50%     79795.000000  1260.785500   448.453150   235.888750      0.850250
# 75%     88980.000000  1599.479000   467.515200   257.433625      0.875375
# max    124008.000000  2755.049100   535.642200   383.046100      0.946000
#
#            EQDIASQ     SOLIDITY    CONVEX_AREA       EXTENT  ASPECT_RATIO  \
# count  1718.000000  1718.000000    1718.000000  1718.000000   1718.000000
# mean    317.790000     0.940103   84947.671129     0.716055      1.899342
# std      26.571699     0.050006   13081.742551     0.052534      0.241253
# ...

# %%
# heatmap dari correlation
plt.figure(figsize=(18, 10))
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\abisu\AppData\Local\Temp\ipykernel_23688\2847322348.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %% [markdown]
# Beberapa kolom saling mempunyai kolerasi yang cukup signifikan dengan kolom yang lain.

# %%
data.value_counts("Class")
# Out:
# Class
# Kirmizi_Pistachio    998
# Siit_Pistachio       720
# dtype: int64

# %%
data.head(5)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107  1161.8070    442.4074    217.7261        0.8705  305.0946    0.9424
# 1  89272  1173.1810    460.2551    251.9546        0.8369  337.1419    0.9641
# 2  60955   999.7890    386.9247    209.1255        0.8414  278.5863    0.9465
# 3  79537  1439.5129    466.7973    221.2136        0.8806  318.2289    0.9437
# 4  96395  1352.6740    515.8730    246.5945        0.8784  350.3340    0.9549
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579  0.7710        2.0319     0.6806       0.6896         0.0061
# 1        92598  0.7584        1.8267     0.8151       0.7325         0.0052
# 2        64400  0.7263        1.8502     0.7663       0.7200         0.0063
# 3        84281  0.7568        2.1102     0.4823       0.6817         0.0059
# 4       100950  0.7428        2.0920     0.6620       0.6791         0.0054
#
# ...

# %%
data['AREA'].unique()
# Out:
# array([73107, 89272, 60955, ..., 90270, 73148, 78780], dtype=int64)

# %%
# Scatter Plot dari age dan y beserta perbandingan sex
sns.scatterplot(data, x='MAJOR_AXIS', y='MINOR_AXIS', hue='Class')
plt.show()

# %% [markdown]
# Kelas Siit mempunyai rentan minor axis diatas 200 dan major axis diatas 400

# %%
# Scatter Plot dari age dan y beserta perbandingan sex
sns.scatterplot(data, x='ROUNDNESS', y='COMPACTNESS', hue='Class')
plt.show()

# %% [markdown]
# Kelas Siit rata-rata mempunyai nilai compactness diatas 0.7

# %%
# Scatter Plot dari age dan y beserta perbandingan sex
sns.scatterplot(data, x='ROUNDNESS', y='ASPECT_RATIO', hue='Class')
plt.show()

# %% [markdown]
# Kelas Kirmizi rata-rata mempunyai aspect ratio diatas 1.75

# %% [markdown]
# Dari hasil heatmap correlation dan scatter plot diatas bisa disimpulkan bahwa klasifikasi dengan machine learning dibutuhkan karena saling ketergantungannya fitur-fitur tersebut.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Di bagian Feature Engineering tahap-tahap untuk mempersiapkan pelatihan model klasifikasi. Mulai dari feature selection, splitting X dan y dan juga splitting untuk training/testing dataset, Handling outliers jika ada, scalling, dan encoding

# %% [markdown]
# ## Feature Selection

# %%
data.head(5)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107  1161.8070    442.4074    217.7261        0.8705  305.0946    0.9424
# 1  89272  1173.1810    460.2551    251.9546        0.8369  337.1419    0.9641
# 2  60955   999.7890    386.9247    209.1255        0.8414  278.5863    0.9465
# 3  79537  1439.5129    466.7973    221.2136        0.8806  318.2289    0.9437
# 4  96395  1352.6740    515.8730    246.5945        0.8784  350.3340    0.9549
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579  0.7710        2.0319     0.6806       0.6896         0.0061
# 1        92598  0.7584        1.8267     0.8151       0.7325         0.0052
# 2        64400  0.7263        1.8502     0.7663       0.7200         0.0063
# 3        84281  0.7568        2.1102     0.4823       0.6817         0.0059
# 4       100950  0.7428        2.0920     0.6620       0.6791         0.0054
#
# ...

# %% [markdown]
# dalam kasus ini user memutuskan untuk menggunaka semua fitur dari dataset. Keputusan ini didukung oleh hasil grafik correlation heatmap yang menunjukan bahwa semua fitur saling mempunyai korelasi yang cukup signifikan dalam penentuan klasifikasi kelas pistachio.

# %% [markdown]
# ## Split between X (features) and y (Target)

# %%
##Splitting between X and y

X = data.drop(['Class'], axis = 1)
y = data['Class']
X
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0     73107  1161.8070    442.4074    217.7261        0.8705  305.0946
# 1     89272  1173.1810    460.2551    251.9546        0.8369  337.1419
# 2     60955   999.7890    386.9247    209.1255        0.8414  278.5863
# 3     79537  1439.5129    466.7973    221.2136        0.8806  318.2289
# 4     96395  1352.6740    515.8730    246.5945        0.8784  350.3340
# ...     ...        ...         ...         ...           ...       ...
# 1713  65570  2071.4451    418.0258    217.1458        0.8545  288.9400
# 1714  68849  1441.2590    451.0457    205.2553        0.8905  296.0764
# 1715  90270  1370.5380    428.9636    269.8232        0.7774  339.0211
# 1716  73148  1309.8430    469.0491    208.3141        0.8960  305.1801
# 1717  78780  1324.8831    451.5905    239.3016        0.8481  316.7109
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
y
# Out:
# 0       Kirmizi_Pistachio
# 1          Siit_Pistachio
# 2       Kirmizi_Pistachio
# 3       Kirmizi_Pistachio
# 4       Kirmizi_Pistachio
#               ...
# 1713    Kirmizi_Pistachio
# 1714    Kirmizi_Pistachio
# 1715       Siit_Pistachio
# 1716    Kirmizi_Pistachio
# 1717       Siit_Pistachio
# Name: Class, Length: 1718, dtype: object

# %% [markdown]
# ## Splitting dataset into train and test dataset

# %%
#Splitting between train set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 27)


print('Train size : ', X_train.shape)
print('Test size : ', X_test.shape)
X_train
# Out:
# Train size :  (1374, 16)
# Test size :  (344, 16)
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 1152  89993  1193.9139    464.8350    247.4356        0.8466  338.5006
# 502   75582  1175.7490    461.3922    215.4832        0.8842  310.2160
# 1204  89960  1213.4139    474.2642    249.1864        0.8508  338.4385
# 949   60411  1880.8440    425.6987    202.7384        0.8793  277.3404
# 1154  63714  1652.2080    415.7028    222.0418        0.8454  284.8213
# ...     ...        ...         ...         ...           ...       ...
# 1048  79613  1191.8831    464.9195    220.2775        0.8806  318.3809
# 1317  64036  1162.1090    415.7550    205.7012        0.8690  285.5401
# 752   54954  1991.1689    377.7057    268.5568        0.7032  264.5177
# 543   74534  1233.4010    478.2781    204.0783        0.9044  308.0578
# 1043  81715  1210.4821    466.1080    228.0202        0.8722  322.5566
#
# ...

# %% [markdown]
# ## Handling Outliers

# %%
# Handling outlier
def diagnostic_plots(df, variable):
    # Define figure size
    plt.figure(figsize=(16, 4))

    # Histogram
    plt.subplot(1, 2, 1)
    sns.histplot(df[variable], bins=30)
    plt.title('Histogram')

    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(y=df[variable])
    plt.title('Boxplot')

    plt.show()

# %%
X_train
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 1152  89993  1193.9139    464.8350    247.4356        0.8466  338.5006
# 502   75582  1175.7490    461.3922    215.4832        0.8842  310.2160
# 1204  89960  1213.4139    474.2642    249.1864        0.8508  338.4385
# 949   60411  1880.8440    425.6987    202.7384        0.8793  277.3404
# 1154  63714  1652.2080    415.7028    222.0418        0.8454  284.8213
# ...     ...        ...         ...         ...           ...       ...
# 1048  79613  1191.8831    464.9195    220.2775        0.8806  318.3809
# 1317  64036  1162.1090    415.7550    205.7012        0.8690  285.5401
# 752   54954  1991.1689    377.7057    268.5568        0.7032  264.5177
# 543   74534  1233.4010    478.2781    204.0783        0.9044  308.0578
# 1043  81715  1210.4821    466.1080    228.0202        0.8722  322.5566
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
# Inspeksi variable AREA from the dataframe

diagnostic_plots(X_train, 'AREA')
print('\nSkewness Value : ', X_train['AREA'].skew())
# Out:
# Skewness Value :  -0.2145287070602986

# %%
# Inspeksi variable PERIMETER from the dataframe

diagnostic_plots(X_train, 'PERIMETER')
print('\nSkewness Value : ', X_train['PERIMETER'].skew())
# Out:
# Skewness Value :  1.4343431974872793

# %%
# Inspeksi variable MAJOR_AXIS from the dataframe

diagnostic_plots(X_train, 'MAJOR_AXIS')
print('\nSkewness Value : ', X_train['MAJOR_AXIS'].skew())
# Out:
# Skewness Value :  -0.4961970118259138

# %%
# Inspeksi variable MINOR_AXIS from the dataframe

diagnostic_plots(X_train, 'MINOR_AXIS')
print('\nSkewness Value : ', X_train['MINOR_AXIS'].skew())
# Out:
# Skewness Value :  0.19855584799096643

# %%
# Inspeksi variable ECCENTRICITY from the dataframe

diagnostic_plots(X_train, 'ECCENTRICITY')
print('\nSkewness Value : ', X_train['ECCENTRICITY'].skew())
# Out:
# Skewness Value :  -1.4934040736878313

# %%
data.head(2)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107   1161.807    442.4074    217.7261        0.8705  305.0946    0.9424
# 1  89272   1173.181    460.2551    251.9546        0.8369  337.1419    0.9641
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579  0.7710        2.0319     0.6806       0.6896         0.0061
# 1        92598  0.7584        1.8267     0.8151       0.7325         0.0052
#
#    SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4              Class
# 0         0.0030         0.4756         0.9664  Kirmizi_Pistachio
# 1         0.0028         0.5366         0.9802     Siit_Pistachio

# %%
# Inspeksi variable EQDIASQ from the dataframe

diagnostic_plots(X_train, 'EQDIASQ')
print('\nSkewness Value : ', X_train['EQDIASQ'].skew())
# Out:
# Skewness Value :  -0.5501486339394365

# %%
# Inspeksi variable SOLIDITY from the dataframe

diagnostic_plots(X_train, 'SOLIDITY')
print('\nSkewness Value : ', X_train['SOLIDITY'].skew())
# Out:
# Skewness Value :  -1.9954979803807888

# %%
data.head(1)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107   1161.807    442.4074    217.7261        0.8705  305.0946    0.9424
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579   0.771        2.0319     0.6806       0.6896         0.0061
#
#    SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4              Class
# 0          0.003         0.4756         0.9664  Kirmizi_Pistachio

# %%
# Inspeksi variable CONVEX_AREA from the dataframe

diagnostic_plots(X_train, 'CONVEX_AREA')
print('\nSkewness Value : ', X_train['CONVEX_AREA'].skew())
# Out:
# Skewness Value :  -0.13780759643815282

# %%
# Inspeksi variable ASPECT_RATIO from the dataframe

diagnostic_plots(X_train, 'ASPECT_RATIO')
print('\nSkewness Value : ', X_train['ASPECT_RATIO'].skew())
# Out:
# Skewness Value :  0.26860832562059384

# %%
# Inspeksi variable ROUNDNESS from the dataframe

diagnostic_plots(X_train, 'ROUNDNESS')
print('\nSkewness Value : ', X_train['ROUNDNESS'].skew())
# Out:
# Skewness Value :  -0.5963247004873783

# %%
# Inspeksi variable COMPACTNESS from the dataframe

diagnostic_plots(X_train, 'COMPACTNESS')
print('\nSkewness Value : ', X_train['COMPACTNESS'].skew())
# Out:
# Skewness Value :  0.016217819111722865

# %%
# Inspeksi variable SHAPEFACTOR_1 from the dataframe

diagnostic_plots(X_train, 'SHAPEFACTOR_1')
print('\nSkewness Value : ', X_train['SHAPEFACTOR_1'].skew())
# Out:
# Skewness Value :  1.923541105975682

# %%
# Inspeksi variable SHAPEFACTOR_2 from the dataframe

diagnostic_plots(X_train, 'SHAPEFACTOR_2')
print('\nSkewness Value : ', X_train['SHAPEFACTOR_2'].skew())
# Out:
# Skewness Value :  2.0479664439678613

# %%
# Inspeksi variable SHAPEFACTOR_3 from the dataframe

diagnostic_plots(X_train, 'SHAPEFACTOR_3')
print('\nSkewness Value : ', X_train['SHAPEFACTOR_3'].skew())
# Out:
# Skewness Value :  0.28694146550659494

# %%
# Inspeksi variable SHAPEFACTOR_4 from the dataframe

diagnostic_plots(X_train, 'SHAPEFACTOR_4')
print('\nSkewness Value : ', X_train['SHAPEFACTOR_4'].skew())
# Out:
# Skewness Value :  -2.8020239604394876

# %% [markdown]
# ### Outlier detection for Normally distributed variables

# %%
# Function to find upper and lower boundaries for normally distributed variables
# Calculate the boundaries outside which sit the outliers for a Gaussian distribution

def find_normal_boundaries(df, variable):
    upper_boundary = df[variable].mean() + 3 * df[variable].std()
    lower_boundary = df[variable].mean() - 3 * df[variable].std()

    return upper_boundary, lower_boundary

# %%
data.head(1)
# Out:
#     AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0  73107   1161.807    442.4074    217.7261        0.8705  305.0946    0.9424
#
#    CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_1  \
# 0        77579   0.771        2.0319     0.6806       0.6896         0.0061
#
#    SHAPEFACTOR_2  SHAPEFACTOR_3  SHAPEFACTOR_4              Class
# 0          0.003         0.4756         0.9664  Kirmizi_Pistachio

# %%
# calculate boundaries for AREA
upper_boundary, lower_boundary = find_normal_boundaries(X_train, 'AREA')
upper_boundary, lower_boundary
# Out:
# (118692.62504316043, 40996.88878507828)

# %%
# Inspect the number and percentage of outliers for `AREA`

print('Total train data entries: {}'.format(len(X_train)))
print('Data entries with more than 120000 Area (right end outliers) : {}'.format(len(X_train[X_train['AREA'] > upper_boundary])))
print('Data entries with less than 41000 Area (left end outliers)  : {}'.format(len(X_train[X_train['AREA'] < lower_boundary])))
print('')
print('% right end outliers : {}'.format(len(X_train[X_train['AREA'] > upper_boundary]) / len(X_train) * 100))
print('% left end outliers  : {}'.format(len(X_train[X_train['AREA'] < lower_boundary]) / len(X_train) * 100))
# Out:
# Total train data entries: 1374
# Data entries with more than 120000 Area (right end outliers) : 1
# Data entries with less than 41000 Area (left end outliers)  : 8
#
# % right end outliers : 0.0727802037845706
# % left end outliers  : 0.5822416302765648

# %%
# calculate boundaries for MINOR_AXIS
upper_boundary, lower_boundary = find_normal_boundaries(X_train, 'MINOR_AXIS')
upper_boundary, lower_boundary
# Out:
# (329.29319242292365, 146.89327599046786)

# %%
# Inspect the number and percentage of outliers for `MINOR_AXIS`

print('Total data entries: {}'.format(len(X_train)))
print('Data entries with more than 330 minor axis (right end outliers) : {}'.format(len(X_train[X_train['MINOR_AXIS'] > upper_boundary])))
print('Data entries with less than 147 Area (left end outliers)  : {}'.format(len(X_train[X_train['MINOR_AXIS'] < lower_boundary])))
print('')
print('% right end outliers : {}'.format(len(X_train[X_train['MINOR_AXIS'] > upper_boundary]) / len(X_train) * 100))
print('% left end outliers  : {}'.format(len(X_train[X_train['MINOR_AXIS'] < lower_boundary]) / len(X_train) * 100))
# Out:
# Total data entries: 1374
# Data entries with more than 330 minor axis (right end outliers) : 7
# Data entries with less than 147 Area (left end outliers)  : 6
#
# % right end outliers : 0.5094614264919942
# % left end outliers  : 0.43668122270742354

# %%
# calculate boundaries for CONVEX_AREA
upper_boundary, lower_boundary = find_normal_boundaries(X_train, 'CONVEX_AREA')
upper_boundary, lower_boundary
# Out:
# (124111.68088105501, 45761.64371865385)

# %%
# Inspect the number and percentage of outliers for `CONVEX_AREA`

print('Total data entries: {}'.format(len(X_train)))
print('Data entries with more than 125000 convex area (right end outliers) : {}'.format(len(X_train[X_train['CONVEX_AREA'] > upper_boundary])))
print('Data entries with less than 45702 convex area (left end outliers)  : {}'.format(len(X_train[X_train['CONVEX_AREA'] < lower_boundary])))
print('')
print('% right end outliers : {}'.format(len(X_train[X_train['CONVEX_AREA'] > upper_boundary]) / len(X_train) * 100))
print('% left end outliers  : {}'.format(len(X_train[X_train['CONVEX_AREA'] < lower_boundary]) / len(X_train) * 100))
# Out:
# Total data entries: 1374
# Data entries with more than 125000 convex area (right end outliers) : 2
# Data entries with less than 45702 convex area (left end outliers)  : 7
#
# % right end outliers : 0.1455604075691412
# % left end outliers  : 0.5094614264919942

# %%
# calculate boundaries for ASPECT_RATIO
upper_boundary, lower_boundary = find_normal_boundaries(X_train, 'ASPECT_RATIO')
upper_boundary, lower_boundary
# Out:
# (2.6281409817802954, 1.1744297605777831)

# %%
# Inspect the number and percentage of outliers for `ASPECT_RATIO`

print('Total data entries: {}'.format(len(X_train)))
print('Data entries with more than 2.6 aspect ratio (right end outliers) : {}'.format(len(X_train[X_train['ASPECT_RATIO'] > upper_boundary])))
print('Data entries with less than 1.2 aspect ratio (left end outliers)  : {}'.format(len(X_train[X_train['ASPECT_RATIO'] < lower_boundary])))
print('')
print('% right end outliers : {}'.format(len(X_train[X_train['ASPECT_RATIO'] > upper_boundary]) / len(X_train) * 100))
print('% left end outliers  : {}'.format(len(X_train[X_train['ASPECT_RATIO'] < lower_boundary]) / len(X_train) * 100))
# Out:
# Total data entries: 1374
# Data entries with more than 2.6 aspect ratio (right end outliers) : 9
# Data entries with less than 1.2 aspect ratio (left end outliers)  : 1
#
# % right end outliers : 0.6550218340611353
# % left end outliers  : 0.0727802037845706

# %%
# calculate boundaries for COMPACTNESS
upper_boundary, lower_boundary = find_normal_boundaries(X_train, 'COMPACTNESS')
upper_boundary, lower_boundary
# Out:
# (0.8442546470638959, 0.5803751928196557)

# %%
# Inspect the number and percentage of outliers for `COMPACTNESS`

print('Total data entries: {}'.format(len(X_train)))
print('Data entries with more than 0.9 compactness (right end outliers) : {}'.format(len(X_train[X_train['COMPACTNESS'] > upper_boundary])))
print('Data entries with less than 0.6 compactness (left end outliers)  : {}'.format(len(X_train[X_train['COMPACTNESS'] < lower_boundary])))
print('')
print('% right end outliers : {}'.format(len(X_train[X_train['COMPACTNESS'] > upper_boundary]) / len(X_train) * 100))
print('% left end outliers  : {}'.format(len(X_train[X_train['COMPACTNESS'] < lower_boundary]) / len(X_train) * 100))
# Out:
# Total data entries: 1374
# Data entries with more than 0.9 compactness (right end outliers) : 5
# Data entries with less than 0.6 compactness (left end outliers)  : 5
#
# % right end outliers : 0.363901018922853
# % left end outliers  : 0.363901018922853

# %%
# calculate boundaries for SHAPEFACTOR_3
upper_boundary, lower_boundary = find_normal_boundaries(X_train, 'SHAPEFACTOR_3')
upper_boundary, lower_boundary
# Out:
# (0.697654442541183, 0.32099563023902067)

# %%
# Inspect the number and percentage of outliers for `SHAPEFACTOR_3`

print('Total data entries: {}'.format(len(X_train)))
print('Data entries with more than 0.7 shape factor 3 (right end outliers) : {}'.format(len(X_train[X_train['SHAPEFACTOR_3'] > upper_boundary])))
print('Data entries with less than 0.32 shape factor 3 (left end outliers)  : {}'.format(len(X_train[X_train['SHAPEFACTOR_3'] < lower_boundary])))
print('')
print('% right end outliers : {}'.format(len(X_train[X_train['SHAPEFACTOR_3'] > upper_boundary]) / len(X_train) * 100))
print('% left end outliers  : {}'.format(len(X_train[X_train['SHAPEFACTOR_3'] < lower_boundary]) / len(X_train) * 100))
# Out:
# Total data entries: 1374
# Data entries with more than 0.7 shape factor 3 (right end outliers) : 7
# Data entries with less than 0.32 shape factor 3 (left end outliers)  : 5
#
# % right end outliers : 0.5094614264919942
# % left end outliers  : 0.363901018922853

# %% [markdown]
# ### Outlier detection for skewed variables

# %%
# Function to find upper and lower boundaries for skewed distributed variables
# Let's calculate the boundaries outside which sit the outliers for skewed distributions
# Distance passed as an argument, gives us the option to estimate 1.5 times or 3 times the IQR to calculate the boundaries.

def find_skewed_boundaries(df, variable, distance):
    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)

    lower_boundary = df[variable].quantile(0.25) - (IQR * distance)
    upper_boundary = df[variable].quantile(0.75) + (IQR * distance)

    return upper_boundary, lower_boundary

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'PERIMETER', 3)
upper_boundary, lower_boundary
# Out:
# (2775.3651999999997, -38.63777499999992)

# %%
# Lets look at the number and percentage of outliers for `PERIMETER`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with perimeter bigger than 2775   : {}'.format(len(X_train[X_train['PERIMETER'] > upper_boundary])))
print('')
print('% datas with perimeter bigger than 2775 : {}'.format(len(X_train[X_train['PERIMETER'] > upper_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with perimeter bigger than 2775   : 0
#
# % datas with perimeter bigger than 2775 : 0.0

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'MAJOR_AXIS', 3)
upper_boundary, lower_boundary
# Out:
# (586.4306250000001, 308.18902499999996)

# %%
# Lets look at the number and percentage of outliers for `MAJOR_AXIS`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with major axis lower than 308   : {}'.format(len(X_train[X_train['MAJOR_AXIS'] < lower_boundary])))
print('')
print('% datas with major axis lower than 308 : {}'.format(len(X_train[X_train['MAJOR_AXIS'] < lower_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with major axis lower than 308   : 0
#
# % datas with major axis lower than 308 : 0.0

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'ECCENTRICITY', 3)
upper_boundary, lower_boundary
# Out:
# (1.0483249999999997, 0.6446000000000003)

# %%
# Lets look at the number and percentage of outliers for `ECCENTRICITY`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with eccentricity lower than 0.6   : {}'.format(len(X_train[X_train['ECCENTRICITY'] < lower_boundary])))
print('')
print('% datas with eccentricity lower than 0.6 : {}'.format(len(X_train[X_train['ECCENTRICITY'] < lower_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with eccentricity lower than 0.6   : 9
#
# % datas with eccentricity lower than 0.6 : 0.6550218340611353

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'EQDIASQ', 3)
upper_boundary, lower_boundary
# Out:
# (437.50174999999996, 200.98680000000002)

# %%
# Lets look at the number and percentage of outliers for `EQDIASQ`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with EQDIASQ lower than 201   : {}'.format(len(X_train[X_train['EQDIASQ'] < lower_boundary])))
print('')
print('% datas with EQDIASQ lower than 201 : {}'.format(len(X_train[X_train['EQDIASQ'] < lower_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with EQDIASQ lower than 201   : 1
#
# % datas with EQDIASQ lower than 201 : 0.0727802037845706

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'SOLIDITY', 3)
upper_boundary, lower_boundary
# Out:
# (1.1467249999999996, 0.7508750000000004)

# %%
# Lets look at the number and percentage of outliers for `SOLIDITY`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with SOLIDITY lower than 0.75   : {}'.format(len(X_train[X_train['SOLIDITY'] < lower_boundary])))
print('')
print('% datas with SOLIDITY lower than 0.75 : {}'.format(len(X_train[X_train['SOLIDITY'] < lower_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with SOLIDITY lower than 0.75   : 17
#
# % datas with SOLIDITY lower than 0.75 : 1.2372634643377

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'SHAPEFACTOR_1', 3)
upper_boundary, lower_boundary
# Out:
# (0.008800000000000002, 0.002499999999999998)

# %%
# Lets look at the number and percentage of outliers for `SHAPEFACTOR_1`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with SHAPEFACTOR_1 bigger than 0.008   : {}'.format(len(X_train[X_train['SHAPEFACTOR_1'] > upper_boundary])))
print('')
print('% datas with SHAPEFACTOR_1 bigger than 0.008 : {}'.format(len(X_train[X_train['SHAPEFACTOR_1'] > upper_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with SHAPEFACTOR_1 bigger than 0.008   : 9
#
# % datas with SHAPEFACTOR_1 bigger than 0.008 : 0.6550218340611353

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'SHAPEFACTOR_2', 3)
upper_boundary, lower_boundary
# Out:
# (0.004400000000000001, 0.0015999999999999994)

# %%
# Lets look at the number and percentage of outliers for `SHAPEFACTOR_2`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with SHAPEFACTOR_2 bigger than 0.004   : {}'.format(len(X_train[X_train['SHAPEFACTOR_2'] > upper_boundary])))
print('')
print('% datas with SHAPEFACTOR_2 bigger than 0.004 : {}'.format(len(X_train[X_train['SHAPEFACTOR_2'] > upper_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with SHAPEFACTOR_2 bigger than 0.004   : 9
#
# % datas with SHAPEFACTOR_2 bigger than 0.004 : 0.6550218340611353

# %%
# Looking for outliers, using the interquantile proximity rule IQR * 3

upper_boundary, lower_boundary = find_skewed_boundaries(X_train, 'SHAPEFACTOR_4', 3)
upper_boundary, lower_boundary
# Out:
# (1.116925, 0.8147000000000002)

# %%
# Lets look at the number and percentage of outliers for `SHAPEFACTOR_4`

print('Total data entries : {}'.format(len(X_train)))
print('Data entries with SHAPEFACTOR_4 lower than 0.814   : {}'.format(len(X_train[X_train['SHAPEFACTOR_4'] < lower_boundary])))
print('')
print('% datas with SHAPEFACTOR_4 lower than 0.814 : {}'.format(len(X_train[X_train['SHAPEFACTOR_4'] < lower_boundary])/len(X_train) * 100))
# Out:
# Total data entries : 1374
# Data entries with SHAPEFACTOR_4 lower than 0.814   : 42
#
# % datas with SHAPEFACTOR_4 lower than 0.814 : 3.056768558951965

# %% [markdown]
# ## Censoring

# %%
from feature_engine.outliers import Winsorizer

# %% [markdown]
# ### Skewed distribution

# %%
# Pembuatan left capper

windsoriser = Winsorizer(capping_method='iqr', # choose iqr for IQR rule boundaries or gaussian for mean and std
                          tail='both', # cap left, right or both tails 
                          fold=1.5,
                          variables=['ECCENTRICITY', 'EQDIASQ', 'SOLIDITY', 'SHAPEFACTOR_4'])

windsoriser.fit(X_train)

X_train_t = windsoriser.transform(X_train)
X_test_t = windsoriser.transform(X_test)

# %%
# Pembuatan right capper

windsoriser_2 = Winsorizer(capping_method='iqr', # choose iqr for IQR rule boundaries or gaussian for mean and std
                          tail='right', # cap left, right or both tails 
                          fold=1.5,
                          variables=['SHAPEFACTOR_1', 'SHAPEFACTOR_2'])

windsoriser_2.fit(X_train_t)

X_train_t = windsoriser.transform(X_train_t)
X_test_t = windsoriser.transform(X_test_t)

# %% [markdown]
# ### Gaussian distribution

# %%
# Pembuatan capper

windsoriser = Winsorizer(capping_method='gaussian', # choose iqr for IQR rule boundaries or gaussian for mean and std
                          tail='left', # cap left, right or both tails 
                          fold=2,
                          variables=['AREA', 'MINOR_AXIS', 'CONVEX_AREA', 'ASPECT_RATIO', 'COMPACTNESS', 'SHAPEFACTOR_3'])

windsoriser.fit(X_train)

X_train_t = windsoriser.transform(X_train)
X_test_t = windsoriser.transform(X_test)

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# Feature scalling dibutuhkan agar model lebih akurat dalam proses prediksi

# %%
#Feature scaling using MinmaxScaler

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(X_train_t)
X_train_scaled = scaler.transform(X_train_t)
X_test_scaled = scaler.transform(X_test_t)
X_train_scaled
# Out:
# array([[0.51443488, 0.1769143 , 0.66945994, ..., 0.07142857, 0.39347087,
#         0.99286658],
#        [0.30871743, 0.16733713, 0.65338837, ..., 0.14285714, 0.18341517,
#         0.91809775],
#        [0.5139638 , 0.18719539, 0.71347705, ..., 0.10714286, 0.33679344,
#         0.92153236],
#        ...,
#        [0.01425213, 0.59725534, 0.26272555, ..., 0.85714286, 0.28656273,
#         0.18335535],
#        [0.2937572 , 0.1977333 , 0.73221462, ..., 0.07142857, 0.08349097,
#         0.92972259],
#        [0.39626619, 0.18564964, 0.67540252, ..., 0.10714286, 0.25540357,
#         0.94715984]])

# %% [markdown]
# ## Encoding

# %%
# Encoding output y
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(y_train)

y_train_enc = encoder.transform(y_train)
y_test_enc = encoder.transform(y_test)
y_train_enc
# Out:
# array([1, 0, 0, ..., 0, 0, 0])

# %%
labels = dict(zip(encoder.transform(encoder.classes_), encoder.classes_))
print(labels)
# Out:
# {0: 'Kirmizi_Pistachio', 1: 'Siit_Pistachio'}

# %% [markdown]
# ## Concating Columns and Create Final Dataframe

# %%
col_list = list(X_train.columns)
col_list
# Out:
# ['AREA',
#  'PERIMETER',
#  'MAJOR_AXIS',
#  'MINOR_AXIS',
#  'ECCENTRICITY',
#  'EQDIASQ',
#  'SOLIDITY',
#  'CONVEX_AREA',
#  'EXTENT',
#  'ASPECT_RATIO',
#  'ROUNDNESS',
#  'COMPACTNESS',
#  'SHAPEFACTOR_1',
#  'SHAPEFACTOR_2',
#  'SHAPEFACTOR_3',
#  'SHAPEFACTOR_4']

# %%
#Create dataframe of X_train_final

X_train_final = pd.DataFrame(X_train_scaled, columns = [col_list])
X_train_final.head(30)
# Out:
#         AREA PERIMETER MAJOR_AXIS MINOR_AXIS ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0   0.514435  0.176914   0.669460   0.340835     0.774654  0.701636  0.975436
# 1   0.308717  0.167337   0.653388   0.185523     0.859896  0.558248  0.900761
# 2   0.513964  0.187195   0.713477   0.349345     0.784176  0.701321  0.911570
# 3   0.092151  0.539088   0.486765   0.123574     0.848787  0.391587  0.695161
# 4   0.139301  0.418543   0.440102   0.217403     0.771934  0.429511  0.654630
# 5   0.164854  0.212766   0.489213   0.123578     0.849467  0.449653  0.922623
# 6   0.150679  0.101244   0.482425   0.093271     0.865337  0.438514  0.948907
# 7   0.603925  0.338160   0.823117   0.343978     0.820676  0.760399  0.951118
# 8   0.463088  0.494643   0.827112   0.266300     0.861709  0.666991  0.748710
# 9   0.476292  0.157022   0.670442   0.305219     0.796871  0.675968  0.995333
# 10  0.165482  0.667851   0.681670   0.193195     0.863296  0.450145  0.435765
# ...

# %%
#Create dataframe of X_test_final

X_test_final = pd.DataFrame(X_test_scaled, columns = [col_list])
X_test_final.head(30)
# Out:
#         AREA PERIMETER MAJOR_AXIS MINOR_AXIS ECCENTRICITY   EQDIASQ  SOLIDITY  \
# 0   0.198614  0.469241   0.380935   0.318476     0.664702  0.475848  0.722427
# 1   0.261082  0.152858   0.536907   0.214575     0.808887  0.523140  0.888234
# 2   0.241011  0.210526   0.596469   0.144191     0.867377  0.508106  0.883567
# 3   0.336896  0.143139   0.445720   0.315157     0.700748  0.578652  0.973717
# 4   0.647578  0.299923   0.795726   0.402565     0.779415  0.788369  0.935397
# 5   0.351700  0.668579   0.626636   0.266381     0.806166  0.589267  0.839352
# 6   0.325348  0.338977   0.674612   0.196663     0.859669  0.570322  0.796365
# 7   0.492052  0.246978   0.806855   0.257245     0.861483  0.686620  0.956276
# 8   0.139644  0.138468   0.402474   0.120218     0.824303  0.429784  0.904937
# 9   0.424673  0.596887   0.579792   0.518393     0.602584  0.640599  0.676984
# 10  0.766874  0.258234   0.771202   0.512869     0.700295  0.862680  0.974699
# ...

# %% [markdown]
# # Model Definition

# %%
#Importing models

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import NearestNeighbors, KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
svm_clf = SVC()
tree_clf = DecisionTreeClassifier()
rf_clf = RandomForestClassifier()
knn_clf = KNeighborsClassifier()
nb_model = GaussianNB()

# %%
# Model Fitting
svm_clf.fit(X_train_final,y_train_enc)
tree_clf.fit(X_train_final,y_train_enc)
rf_clf.fit(X_train_final,y_train_enc)
knn_clf.fit(X_train_final,y_train_enc)
nb_model.fit(X_train_final,y_train_enc)
# Out:
# GaussianNB()

# %% [markdown]
# ## Model Training and Testing

# %%
#Model Training and Testing

svm_clf_train = svm_clf.predict(X_train_final)
svm_clf_test = svm_clf.predict(X_test_final)

tree_pred_train = tree_clf.predict(X_train_final)
tree_pred_test = tree_clf.predict(X_test_final)

rf_pred_train = rf_clf.predict(X_train_final)
rf_pred_test = rf_clf.predict(X_test_final)

knn_pred_train = knn_clf.predict(X_train_final)
knn_pred_test = knn_clf.predict(X_test_final)

nb_pred_train = nb_model.predict(X_train_final)
nb_pred_test = nb_model.predict(X_test_final)

# %% [markdown]
# # Model Evaluation

# %%
#importing libraries for model evaluation
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, accuracy_score, f1_score, ConfusionMatrixDisplay

# %% [markdown]
# Semua model akan dievaluasi setelah training dan testing dengan menghitung Accuracy score, classification report, F1 Score, dan cross validation score dari training dan testing. Semua hasil model evaluasi akan dibandingkan untuk mengetahui model yang paling efektif untuk kasus ini.

# %% [markdown]
# ## SVM

# %%
y_pred_train_svm = svm_clf_train
y_pred_test_svm = svm_clf_test

# %%
print('accuracy score train : ',accuracy_score(y_train_enc,y_pred_train_svm))
print('accuracy score test : ',accuracy_score(y_test_enc,y_pred_test_svm))
# Out:
# accuracy score train :  0.8791848617176128
# accuracy score test :  0.8808139534883721

# %%
cm = confusion_matrix(y_train_enc, y_pred_train_svm, labels=svm_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=svm_clf.classes_)

disp.plot()
plt.show()

# %%
print('Classification Report of train set: \n', classification_report(y_train_enc,y_pred_train_svm), '\n')
print('Classification Report of test set: \n', classification_report(y_test_enc,y_pred_test_svm))
# Out:
# Classification Report of train set:
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       795
#            1       0.87      0.84      0.85       579
#
#     accuracy                           0.88      1374
#    macro avg       0.88      0.87      0.88      1374
# weighted avg       0.88      0.88      0.88      1374
#
#
# Classification Report of test set:
#                precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       203
#            1       0.86      0.84      0.85       141
#
#     accuracy                           0.88       344
#    macro avg       0.88      0.88      0.88       344
# weighted avg       0.88      0.88      0.88       344

# %%
# Cross Validation using `cross_val_score`


from sklearn.model_selection import cross_val_score

f1_score_train_cross_val = cross_val_score(svm_clf, 
                                           X_train_final, 
                                           y_train_enc, 
                                           cv=3, 
                                           scoring='f1')

print('F1 Score - All - Cross Validation  : ', f1_score_train_cross_val)
print('F1 Score - Mean - Cross Validation : ', f1_score_train_cross_val.mean())
print('F1 Score - Std - Cross Validation  : ', f1_score_train_cross_val.std())
print('F1 Score - Range of Test-Set       : ', (f1_score_train_cross_val.mean()-f1_score_train_cross_val.std()) , '-', (f1_score_train_cross_val.mean()+f1_score_train_cross_val.std()))
# Out:
# F1 Score - All - Cross Validation  :  [0.84183673 0.864      0.83957219]
# F1 Score - Mean - Cross Validation :  0.8484696424024155
# F1 Score - Std - Cross Validation  :  0.011020467115129187
# F1 Score - Range of Test-Set       :  0.8374491752872864 - 0.8594901095175447

# %%
# Check Performance Model against Test-Set


print('F1 Score - Test Set   : ', f1_score(y_test_enc, y_pred_test_svm), '\n')
print('Classification Report : \n', classification_report(y_test_enc, y_pred_test_svm), '\n')
print('Confusion Matrix      : \n', ConfusionMatrixDisplay.from_estimator(svm_clf, X_test_final, y_test_enc, cmap='Reds'))
# Out:
# F1 Score - Test Set   :  0.8530465949820788
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       203
#            1       0.86      0.84      0.85       141
#
#     accuracy                           0.88       344
#    macro avg       0.88      0.88      0.88       344
# weighted avg       0.88      0.88      0.88       344
#
#
# Confusion Matrix      :
# ...

# %%
# Save Classification Report into a Dictionary

all_reports = {}
score_reports_svm = {
    'train - precision' : precision_score(y_train_enc, y_pred_train_svm),
    'train - recall' : recall_score(y_train_enc, y_pred_train_svm),
    'train - accuracy' : accuracy_score(y_train_enc, y_pred_train_svm),
    'train - f1_score' : f1_score(y_train_enc, y_pred_train_svm),
    'test - precision' : precision_score(y_test_enc, y_pred_test_svm),
    'test - recall' : recall_score(y_test_enc, y_pred_test_svm),
    'test - accuracy_score' : accuracy_score(y_test_enc, y_pred_test_svm),
    'test - f1_score' : f1_score(y_test_enc, y_pred_test_svm),
}
all_reports['SVM (Default)'] = score_reports_svm
pd.DataFrame(all_reports)
# Out:
#                        SVM (Default)
# test - accuracy_score       0.880814
# test - f1_score             0.853047
# test - precision            0.862319
# test - recall               0.843972
# train - accuracy            0.879185
# train - f1_score            0.854895
# train - precision           0.865487
# train - recall              0.844560

# %% [markdown]
# ## Decision Tree

# %%
y_pred_train_tree = tree_pred_train
y_pred_test_tree = tree_pred_test

# %%
print('accuracy score train : ',accuracy_score(y_train_enc,y_pred_train_tree))
print('accuracy score test : ',accuracy_score(y_test_enc,y_pred_test_tree))
# Out:
# accuracy score train :  1.0
# accuracy score test :  0.8284883720930233

# %%
cm = confusion_matrix(y_train_enc, y_pred_train_tree, labels=tree_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=tree_clf.classes_)

disp.plot()
plt.show()

# %%
print('Classification Report of train set: \n', classification_report(y_train_enc,y_pred_train_tree), '\n')
print('Classification Report of test set: \n', classification_report(y_test_enc,y_pred_test_tree))
# Out:
# Classification Report of train set:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       795
#            1       1.00      1.00      1.00       579
#
#     accuracy                           1.00      1374
#    macro avg       1.00      1.00      1.00      1374
# weighted avg       1.00      1.00      1.00      1374
#
#
# Classification Report of test set:
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       203
#            1       0.80      0.77      0.79       141
#
#     accuracy                           0.83       344
#    macro avg       0.82      0.82      0.82       344
# weighted avg       0.83      0.83      0.83       344

# %%
# Cross Validation using `cross_val_score`


f1_score_train_cross_val = cross_val_score(tree_clf, 
                                           X_train_final, 
                                           y_train_enc, 
                                           cv=3, 
                                           scoring='f1')

print('F1 Score - All - Cross Validation  : ', f1_score_train_cross_val)
print('F1 Score - Mean - Cross Validation : ', f1_score_train_cross_val.mean())
print('F1 Score - Std - Cross Validation  : ', f1_score_train_cross_val.std())
print('F1 Score - Range of Test-Set       : ', (f1_score_train_cross_val.mean()-f1_score_train_cross_val.std()) , '-', (f1_score_train_cross_val.mean()+f1_score_train_cross_val.std()))
# Out:
# F1 Score - All - Cross Validation  :  [0.78606965 0.76683938 0.78534031]
# F1 Score - Mean - Cross Validation :  0.779416448038587
# F1 Score - Std - Cross Validation  :  0.008898314331218637
# F1 Score - Range of Test-Set       :  0.7705181337073683 - 0.7883147623698057

# %%
# Check Performance Model against Test-Set


print('F1 Score - Test Set   : ', f1_score(y_test_enc, y_pred_test_tree), '\n')
print('Classification Report : \n', classification_report(y_test_enc, y_pred_test_tree), '\n')
print('Confusion Matrix      : \n', ConfusionMatrixDisplay.from_estimator(tree_clf, X_test_final, y_test_enc, cmap='Reds'))
# Out:
# F1 Score - Test Set   :  0.7870036101083034
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       203
#            1       0.80      0.77      0.79       141
#
#     accuracy                           0.83       344
#    macro avg       0.82      0.82      0.82       344
# weighted avg       0.83      0.83      0.83       344
#
#
# Confusion Matrix      :
# ...

# %%
# Save Classification Report into a Dictionary

score_reports_tree = {
    'train - precision' : precision_score(y_train_enc, y_pred_train_tree),
    'train - recall' : recall_score(y_train_enc, y_pred_train_tree),
    'train - accuracy' : accuracy_score(y_train_enc, y_pred_train_tree),
    'train - f1_score' : f1_score(y_train_enc, y_pred_train_tree),
    'test - precision' : precision_score(y_test_enc, y_pred_test_tree),
    'test - recall' : recall_score(y_test_enc, y_pred_test_tree),
    'test - accuracy_score' : accuracy_score(y_test_enc, y_pred_test_tree),
    'test - f1_score' : f1_score(y_test_enc, y_pred_test_tree),
}
all_reports['DT (Default)'] = score_reports_tree
pd.DataFrame(all_reports)
# Out:
#                        SVM (Default)  DT (Default)
# train - precision           0.865487      1.000000
# train - recall              0.844560      1.000000
# train - accuracy            0.879185      1.000000
# train - f1_score            0.854895      1.000000
# test - precision            0.862319      0.801471
# test - recall               0.843972      0.773050
# test - accuracy_score       0.880814      0.828488
# test - f1_score             0.853047      0.787004

# %% [markdown]
# ## Random Forest

# %%
y_pred_train_rf = rf_pred_train
y_pred_test_rf = rf_pred_test

# %%
print('accuracy score train : ',accuracy_score(y_train_enc,y_pred_train_rf))
print('accuracy score test : ',accuracy_score(y_test_enc,y_pred_test_rf))
# Out:
# accuracy score train :  1.0
# accuracy score test :  0.8953488372093024

# %%
cm = confusion_matrix(y_train_enc, y_pred_train_rf, labels=rf_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf_clf.classes_)

disp.plot()
plt.show()

# %%
print('Classification Report of train set: \n', classification_report(y_train_enc,y_pred_train_rf), '\n')
print('Classification Report of test set: \n', classification_report(y_test_enc,y_pred_test_rf))
# Out:
# Classification Report of train set:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       795
#            1       1.00      1.00      1.00       579
#
#     accuracy                           1.00      1374
#    macro avg       1.00      1.00      1.00      1374
# weighted avg       1.00      1.00      1.00      1374
#
#
# Classification Report of test set:
#                precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       203
#            1       0.88      0.87      0.87       141
#
#     accuracy                           0.90       344
#    macro avg       0.89      0.89      0.89       344
# weighted avg       0.90      0.90      0.90       344

# %%
# Cross Validation using `cross_val_score`


f1_score_train_cross_val = cross_val_score(rf_clf, 
                                           X_train_final, 
                                           y_train_enc, 
                                           cv=3, 
                                           scoring='f1')

print('F1 Score - All - Cross Validation  : ', f1_score_train_cross_val)
print('F1 Score - Mean - Cross Validation : ', f1_score_train_cross_val.mean())
print('F1 Score - Std - Cross Validation  : ', f1_score_train_cross_val.std())
print('F1 Score - Range of Test-Set       : ', (f1_score_train_cross_val.mean()-f1_score_train_cross_val.std()) , '-', (f1_score_train_cross_val.mean()+f1_score_train_cross_val.std()))
# Out:
# F1 Score - All - Cross Validation  :  [0.82741117 0.83819629 0.83819629]
# F1 Score - Mean - Cross Validation :  0.834601246818996
# F1 Score - Std - Cross Validation  :  0.005084153834757723
# F1 Score - Range of Test-Set       :  0.8295170929842383 - 0.8396854006537536

# %%
# Check Performance Model against Test-Set


print('F1 Score - Test Set   : ', f1_score(y_test_enc, y_pred_test_rf), '\n')
print('Classification Report : \n', classification_report(y_test_enc, y_pred_test_rf), '\n')
print('Confusion Matrix      : \n', ConfusionMatrixDisplay.from_estimator(rf_clf, X_test_final, y_test_enc, cmap='Reds'))
# Out:
# F1 Score - Test Set   :  0.8714285714285713
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       203
#            1       0.88      0.87      0.87       141
#
#     accuracy                           0.90       344
#    macro avg       0.89      0.89      0.89       344
# weighted avg       0.90      0.90      0.90       344
#
#
# Confusion Matrix      :
# ...

# %%
# Save Classification Report into a Dictionary

score_reports_rf = {
    'train - precision' : precision_score(y_train_enc, y_pred_train_rf),
    'train - recall' : recall_score(y_train_enc, y_pred_train_rf),
    'train - accuracy' : accuracy_score(y_train_enc, y_pred_train_rf),
    'train - f1_score' : f1_score(y_train_enc, y_pred_train_rf),
    'test - precision' : precision_score(y_test_enc, y_pred_test_rf),
    'test - recall' : recall_score(y_test_enc, y_pred_test_rf),
    'test - accuracy_score' : accuracy_score(y_test_enc, y_pred_test_rf),
    'test - f1_score' : f1_score(y_test_enc, y_pred_test_rf),
}
all_reports['RF (Default)'] = score_reports_rf
pd.DataFrame(all_reports)
# Out:
#                        SVM (Default)  DT (Default)  RF (Default)
# train - precision           0.865487      1.000000      1.000000
# train - recall              0.844560      1.000000      1.000000
# train - accuracy            0.879185      1.000000      1.000000
# train - f1_score            0.854895      1.000000      1.000000
# test - precision            0.862319      0.801471      0.877698
# test - recall               0.843972      0.773050      0.865248
# test - accuracy_score       0.880814      0.828488      0.895349
# test - f1_score             0.853047      0.787004      0.871429

# %% [markdown]
# ## K-Nearest-neighbor (KNN)

# %%
y_pred_train_knn = knn_pred_train
y_pred_test_knn = knn_pred_test

# %%
print('accuracy score train : ',accuracy_score(y_train_enc,y_pred_train_knn))
print('accuracy score test : ',accuracy_score(y_test_enc,y_pred_test_knn))
# Out:
# accuracy score train :  0.8893740902474527
# accuracy score test :  0.877906976744186

# %%
cm = confusion_matrix(y_train_enc, y_pred_train_knn, labels=knn_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=knn_clf.classes_)

disp.plot()
plt.show()

# %%
print('Classification Report of train set: \n', classification_report(y_train_enc,y_pred_train_knn), '\n')
print('Classification Report of test set: \n', classification_report(y_test_enc,y_pred_test_knn))
# Out:
# Classification Report of train set:
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90       795
#            1       0.86      0.88      0.87       579
#
#     accuracy                           0.89      1374
#    macro avg       0.89      0.89      0.89      1374
# weighted avg       0.89      0.89      0.89      1374
#
#
# Classification Report of test set:
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       203
#            1       0.86      0.84      0.85       141
#
#     accuracy                           0.88       344
#    macro avg       0.87      0.87      0.87       344
# weighted avg       0.88      0.88      0.88       344

# %%
# Cross Validation using `cross_val_score`


f1_score_train_cross_val = cross_val_score(knn_clf, 
                                           X_train_final, 
                                           y_train_enc, 
                                           cv=3, 
                                           scoring='f1')

print('F1 Score - All - Cross Validation  : ', f1_score_train_cross_val)
print('F1 Score - Mean - Cross Validation : ', f1_score_train_cross_val.mean())
print('F1 Score - Std - Cross Validation  : ', f1_score_train_cross_val.std())
print('F1 Score - Range of Test-Set       : ', (f1_score_train_cross_val.mean()-f1_score_train_cross_val.std()) , '-', (f1_score_train_cross_val.mean()+f1_score_train_cross_val.std()))
# Out:
# F1 Score - All - Cross Validation  :  [0.81329923 0.82291667 0.82446809]
# F1 Score - Mean - Cross Validation :  0.8202279948365409
# F1 Score - Std - Cross Validation  :  0.004940143923155621
# F1 Score - Range of Test-Set       :  0.8152878509133852 - 0.8251681387596965

# %%
# Check Performance Model against Test-Set


print('F1 Score - Test Set   : ', f1_score(y_test_enc, y_pred_test_knn), '\n')
print('Classification Report : \n', classification_report(y_test_enc, y_pred_test_knn), '\n')
print('Confusion Matrix      : \n', ConfusionMatrixDisplay.from_estimator(knn_clf, X_test_final, y_test_enc, cmap='Reds'))
# Out:
# F1 Score - Test Set   :  0.85
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       203
#            1       0.86      0.84      0.85       141
#
#     accuracy                           0.88       344
#    macro avg       0.87      0.87      0.87       344
# weighted avg       0.88      0.88      0.88       344
# Confusion Matrix      :
# ...

# %%
# Save Classification Report into a Dictionary

score_reports_knn = {
    'train - precision' : precision_score(y_train_enc, y_pred_train_knn),
    'train - recall' : recall_score(y_train_enc, y_pred_train_knn),
    'train - accuracy' : accuracy_score(y_train_enc, y_pred_train_knn),
    'train - f1_score' : f1_score(y_train_enc, y_pred_train_knn),
    'test - precision' : precision_score(y_test_enc, y_pred_test_knn),
    'test - recall' : recall_score(y_test_enc, y_pred_test_knn),
    'test - accuracy_score' : accuracy_score(y_test_enc, y_pred_test_knn),
    'test - f1_score' : f1_score(y_test_enc, y_pred_test_knn),
}
all_reports['KNN (Default)'] = score_reports_knn
pd.DataFrame(all_reports)
# Out:
#                        SVM (Default)  DT (Default)  RF (Default)  \
# train - precision           0.865487      1.000000      1.000000
# train - recall              0.844560      1.000000      1.000000
# train - accuracy            0.879185      1.000000      1.000000
# train - f1_score            0.854895      1.000000      1.000000
# test - precision            0.862319      0.801471      0.877698
# test - recall               0.843972      0.773050      0.865248
# test - accuracy_score       0.880814      0.828488      0.895349
# test - f1_score             0.853047      0.787004      0.871429
#
#                        KNN (Default)
# train - precision           0.863714
# train - recall              0.875648
# train - accuracy            0.889374
# train - f1_score            0.869640
# test - precision            0.856115
# test - recall               0.843972
# test - accuracy_score       0.877907
# test - f1_score             0.850000

# %% [markdown]
# ## Naive Bayes

# %%
y_pred_train_nb = nb_pred_train
y_pred_test_nb = nb_pred_test

# %%
print('accuracy score train : ',accuracy_score(y_train_enc,y_pred_train_nb))
print('accuracy score test : ',accuracy_score(y_test_enc,y_pred_test_nb))
# Out:
# accuracy score train :  0.8617176128093159
# accuracy score test :  0.8837209302325582

# %%
cm = confusion_matrix(y_train_enc, y_pred_train_nb, labels=nb_model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=nb_model.classes_)

disp.plot()
plt.show()

# %%
print('Classification Report of train set: \n', classification_report(y_train_enc,y_pred_train_nb), '\n')
print('Classification Report of test set: \n', classification_report(y_test_enc,y_pred_test_nb))
# Out:
# Classification Report of train set:
#                precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88       795
#            1       0.82      0.86      0.84       579
#
#     accuracy                           0.86      1374
#    macro avg       0.86      0.86      0.86      1374
# weighted avg       0.86      0.86      0.86      1374
#
#
# Classification Report of test set:
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       203
#            1       0.84      0.89      0.86       141
#
#     accuracy                           0.88       344
#    macro avg       0.88      0.88      0.88       344
# weighted avg       0.89      0.88      0.88       344

# %%
# Cross Validation using `cross_val_score`


from sklearn.model_selection import cross_val_score

f1_score_train_cross_val = cross_val_score(nb_model, 
                                           X_train_final, 
                                           y_train_enc, 
                                           cv=3, 
                                           scoring='f1')

print('F1 Score - All - Cross Validation  : ', f1_score_train_cross_val)
print('F1 Score - Mean - Cross Validation : ', f1_score_train_cross_val.mean())
print('F1 Score - Std - Cross Validation  : ', f1_score_train_cross_val.std())
print('F1 Score - Range of Test-Set       : ', (f1_score_train_cross_val.mean()-f1_score_train_cross_val.std()) , '-', (f1_score_train_cross_val.mean()+f1_score_train_cross_val.std()))
# Out:
# F1 Score - All - Cross Validation  :  [0.83129584 0.85353535 0.828125  ]
# F1 Score - Mean - Cross Validation :  0.8376520656853786
# F1 Score - Std - Cross Validation  :  0.01130553512966672
# F1 Score - Range of Test-Set       :  0.8263465305557119 - 0.8489576008150453

# %%
# Check Performance Model against Test-Set


print('F1 Score - Test Set   : ', f1_score(y_test_enc, y_pred_test_nb), '\n')
print('Classification Report : \n', classification_report(y_test_enc, y_pred_test_nb), '\n')
print('Confusion Matrix      : \n', ConfusionMatrixDisplay.from_estimator(nb_model, X_test_final, y_test_enc, cmap='Reds'))
# Out:
# F1 Score - Test Set   :  0.8620689655172412
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       203
#            1       0.84      0.89      0.86       141
#
#     accuracy                           0.88       344
#    macro avg       0.88      0.88      0.88       344
# weighted avg       0.89      0.88      0.88       344
#
#
# Confusion Matrix      :
# ...

# %%
# Save Classification Report into a Dictionary

score_reports_nb = {
    'train - precision' : precision_score(y_train_enc, y_pred_train_nb),
    'train - recall' : recall_score(y_train_enc, y_pred_train_nb),
    'train - accuracy' : accuracy_score(y_train_enc, y_pred_train_nb),
    'train - f1_score' : f1_score(y_train_enc, y_pred_train_nb),
    'test - precision' : precision_score(y_test_enc, y_pred_test_nb),
    'test - recall' : recall_score(y_test_enc, y_pred_test_nb),
    'test - accuracy_score' : accuracy_score(y_test_enc, y_pred_test_nb),
    'test - f1_score' : f1_score(y_test_enc, y_pred_test_nb),
}
all_reports['NB (Default)'] = score_reports_nb
pd.DataFrame(all_reports)
# Out:
#                        SVM (Default)  DT (Default)  RF (Default)  \
# train - precision           0.865487      1.000000      1.000000
# train - recall              0.844560      1.000000      1.000000
# train - accuracy            0.879185      1.000000      1.000000
# train - f1_score            0.854895      1.000000      1.000000
# test - precision            0.862319      0.801471      0.877698
# test - recall               0.843972      0.773050      0.865248
# test - accuracy_score       0.880814      0.828488      0.895349
# test - f1_score             0.853047      0.787004      0.871429
#
#                        KNN (Default)  NB (Default)
# train - precision           0.863714      0.821488
# train - recall              0.875648      0.858377
# train - accuracy            0.889374      0.861718
# train - f1_score            0.869640      0.839527
# test - precision            0.856115      0.838926
# test - recall               0.843972      0.886525
# ...

# %%
all_reports = pd.DataFrame(all_reports)
all_reports
all_reports.describe()
# Out:
#        SVM (Default)  DT (Default)  RF (Default)  KNN (Default)  NB (Default)
# count       8.000000      8.000000      8.000000       8.000000      8.000000
# mean        0.860535      0.898752      0.938715       0.865796      0.856544
# std         0.014163      0.109345      0.066065       0.015298      0.022447
# min         0.843972      0.773050      0.865248       0.843972      0.821488
# 25%         0.850925      0.797854      0.876131       0.854586      0.839377
# 50%         0.858607      0.914244      0.947674       0.866677      0.860047
# 75%         0.868911      1.000000      1.000000       0.876212      0.867482
# max         0.880814      1.000000      1.000000       0.889374      0.886525

# %%
import dataframe_image as dfi

# %%
dfi.export(all_reports, 'all_reports.png')

# %% [markdown]
# #### Model Improvement

# %% [markdown]
# Model improvement akan diimplementasikan pada random forest dengan menggunakan pipeline dan GridSearchCV.

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# %%
#creating pipeline

pipe = Pipeline ([('classifier', RandomForestClassifier())])

# %%
#dictionary for hyperparameter tuning

grid_param = [
   
    { 'classifier' : [DecisionTreeClassifier()],
      'classifier__criterion': ['gini', 'entropy', 'log_loss'],
      'classifier__max_depth' : [1, 2, 3, 4, None]
    },
    { 'classifier': [RandomForestClassifier()],
      'classifier__n_estimators' : [10, 100, 1000],
      'classifier__max_depth' : [20, 50, 100, None],
      'classifier__min_samples_leaf' : [15, 50, 100],
      'classifier__max_leaf_nodes' : [2, 5, 10]
    },
    { 'classifier': [KNeighborsClassifier()],
      'classifier__n_neighbors' : [1, 5, 10, 15, 20, 30],
      'classifier__weights' : ['uniform', 'distance'],
      'classifier__algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
      'classifier__leaf_size' : [20, 30, 40, 50, 75, 100]
    }

]

# %%
grid = GridSearchCV(pipe, grid_param, cv=5)

# %%
best_model = grid.fit(X_train_final,y_train_enc)

# %%
print(best_model.best_estimator_)
print('\nThe mean score of the best model from training set : ', best_model.score(X_train_final,y_train_enc))
print('The mean score of the best model from test set : ', best_model.score(X_test_final,y_test_enc))
# Out:
# Pipeline(steps=[('classifier',
#                  KNeighborsClassifier(leaf_size=20, n_neighbors=10,
#                                       weights='distance'))])
#
# The mean score of the best model from training set :  1.0
# The mean score of the best model from test set :  0.8808139534883721

# %%
print("Best cross-validation score: {:.4f}".format(grid.best_score_))
print("Test-set score: {:.4f}".format(grid.score(X_test_final, y_test_enc)))
# Out:
# Best cross-validation score: 0.8683
# Test-set score: 0.8808

# %%
rf_clf.score(X_test_final,y_test_enc)
# Out:
# 0.8953488372093024

# %% [markdown]
#     Algoritma dan parameter terbaik setelah aplikasi pipeline dan GridSearchCV adalah KNeighborsClassifier dengan parameter (leaf_size=20, n_neighbors=10,weights='distance'). Hasil score dari test set tersebut adalah 88% yang tidak jauh dengan hasil random forest yaitu 89%. User menentukan Random Forest dengan default parameter sebagai model yang disimpan untuk model inference.

# %% [markdown]
# # Model Saving

# %%
#Save the files

import pickle

with open('model_scaler.pkl', 'wb') as file_1:
  pickle.dump(scaler, file_1)

with open('rf_clf.pkl', 'wb') as file_2:
  pickle.dump(rf_clf, file_2)

# %%
data.head(20)
# Out:
#       AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0    73107  1161.8070    442.4074    217.7261        0.8705  305.0946
# 1    89272  1173.1810    460.2551    251.9546        0.8369  337.1419
# 2    60955   999.7890    386.9247    209.1255        0.8414  278.5863
# 3    79537  1439.5129    466.7973    221.2136        0.8806  318.2289
# 4    96395  1352.6740    515.8730    246.5945        0.8784  350.3340
# 5    74065  1380.5500    405.4317    245.2286        0.7963  307.0871
# 6    91533  1915.9561    451.7373    267.9266        0.8051  341.3846
# 7    77803  2034.9950    455.4354    270.3713        0.8047  314.7409
# 8    90992  1185.5310    468.9019    249.6060        0.8465  340.3742
# 9    83311  1208.8810    473.0142    228.6437        0.8754  325.6913
# 10  100207  2110.7700    476.0792    274.6955        0.8167  357.1939
# 11   75231  1118.5120    436.2821    224.8806        0.8569  309.4949
# ...

# %% [markdown]
# # Model Inference

# %% [markdown]
# Hasil model inference bisa dilihat di file note book 'h8dsft_P1M2_abi_sugiri_Model_Inference.ipynb'

# %% [markdown]
# # Conclusions
#
# Dari hasil prediksi yang sudah dilakukandengan menggunakan beberapa algoritma klasifikasi, bisa disimpulkan bahwa random forest dengan default parameter adalah yang paling akurat dengan menggunakan dataset yang tersedia. Model ini bisa digunakan di perdagangan dan pertanian kacang pistachio.
